# %%
# import stuff
from placerg.funcs import *
from placerg.funcsrg import *
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from placerg.funcsall import *
import matplotlib

# %%
# set up notebook displayt
np.set_printoptions(threshold=5)
alpha=0.4
color='black'
cmap='Greys'
colorline='black'
linethick=3.
colorfit='grey'
plt.style.use('seaborn-paper')
palit=['black', 'firebrick',  \
       'coral', 'goldenrod', 'gold', 'yellowgreen', 'greenyellow', 'lime', 'aquamarine', 'mediumturquoise',\
        'lightskyblue', 'cornflowerblue', 'mediumpurple', 'mediumorchid', 'violet', 'mediumvioletred', \
         'fuchsia', 'deeppink', \
         'hotpink', 'pink' ]
fontsize=80
ticksize=60
fontsizesmall=20
ticksizesmall=16
legendsize=60
legendsizesmall=10
alpha=.3
colorfit='gray'
linecolor='black'
mycmap = cm.copper
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
cmap=cm.binary

# %%
fig, axs = plt.subplots(1,5, figsize=(40,10), sharey=True)
plt.subplots_adjust(hspace=1.0)

envname='/home/mia/OneDrive/simsrg/env_stim10e-16.0et6.0ph0.8p1.0t0.1plNonebp0.5.pkl'
aname='/home/mia/OneDrive/simsrg/a_stim10e-16.0et6.0ph0.8p1.0t0.1plNonebp0.5.pkl'
env=load_object(envname)
a=load_object(aname)
mat=a.pmatarr(4)
mat=np.mean(np.dstack(np.hsplit(mat, 200)), axis=2)
sort=np.argsort(np.argmax(mat,axis=1))
pcm=axs[0].imshow(mat[sort, :], cmap=cmap, aspect="auto")
axs[0].tick_params(axis="y", labelsize=ticksizesmall*2)
axs[0].tick_params(axis='x', labelsize=ticksizesmall*2)
axs[0].set_xlabel('x', fontsize=fontsizesmall*2)
axs[0].set_ylabel('cell index', fontsize=fontsizesmall*2)
cb=fig.colorbar(pcm, ax=axs[0])
cb.ax.tick_params(labelsize=ticksizesmall*2) 


envname='/home/mia/OneDrive/simsrg/env_stim10e-16.0et6.0ph1.0p1.0t0.1plNonebp0.5.pkl'
aname='/home/mia/OneDrive/simsrg/a_stim10e-16.0et6.0ph1.0p1.0t0.1plNonebp0.5.pkl'
env=load_object(envname)
a=load_object(aname)
mat=a.pmatarr(4)
mat=np.mean(np.dstack(np.hsplit(mat, 200)), axis=2)
sort=np.argsort(np.argmax(mat,axis=1))
pcm=axs[1].imshow(mat[sort, :], cmap=cmap, aspect="auto")
axs[1].tick_params(axis="y", labelsize=ticksizesmall*2)
axs[1].tick_params(axis='x', labelsize=ticksizesmall*2)
axs[1].set_xlabel('x', fontsize=fontsizesmall*2)
axs[1].set_ylabel('cell index', fontsize=fontsizesmall*2)
cb=fig.colorbar(pcm, ax=axs[1])
cb.ax.tick_params(labelsize=ticksizesmall*2) 

envname='/home/mia/OneDrive/simsrg/env_stim10e-16.0et6.0ph1.2p1.0t0.1plNonebp0.5.pkl'
aname='/home/mia/OneDrive/simsrg/a_stim10e-16.0et6.0ph1.2p1.0t0.1plNonebp0.5.pkl'
env=load_object(envname)
a=load_object(aname)
mat=a.pmatarr(4)
mat=np.mean(np.dstack(np.hsplit(mat, 200)), axis=2)
sort=np.argsort(np.argmax(mat,axis=1))
pcm=axs[2].imshow(mat[sort, :], cmap=cmap, aspect="auto")
axs[2].tick_params(axis="y", labelsize=ticksizesmall*2)
axs[2].tick_params(axis='x', labelsize=ticksizesmall*2)
axs[2].set_xlabel('x', fontsize=fontsizesmall*2)
axs[2].set_ylabel('cell index', fontsize=fontsizesmall*2)
cb=fig.colorbar(pcm, ax=axs[2])
cb.ax.tick_params(labelsize=ticksizesmall*2) 

envname='/home/mia/OneDrive/simsrg/env_stim10e-16.0et6.0ph1.4p1.0t0.1plNonebp0.5.pkl'
aname='/home/mia/OneDrive/simsrg/a_stim10e-16.0et6.0ph1.4p1.0t0.1plNonebp0.5.pkl'
env=load_object(envname)
a=load_object(aname)
mat=a.pmatarr(4)
mat=np.mean(np.dstack(np.hsplit(mat, 200)), axis=2)
sort=np.argsort(np.argmax(mat,axis=1))
pcm=axs[3].imshow(mat[sort, :], cmap=cmap, aspect="auto")
axs[3].tick_params(axis="y", labelsize=ticksizesmall*2)
axs[3].tick_params(axis='x', labelsize=ticksizesmall*2)
axs[3].set_xlabel('x', fontsize=fontsizesmall*2)
axs[3].set_ylabel('cell index', fontsize=fontsizesmall*2)
cb=fig.colorbar(pcm, ax=axs[3], ticks=[1, 2, 3, 4])
cb.ax.tick_params(labelsize=ticksizesmall*2) 



envname='/home/mia/OneDrive/simsrg/env_stim10e-16.0et6.0ph1.5p1.0t0.1plNonebp0.5.pkl'
aname='/home/mia/OneDrive/simsrg/a_stim10e-16.0et6.0ph1.5p1.0t0.1plNonebp0.5.pkl'
env=load_object(envname)
a=load_object(aname)
mat=a.pmatarr(4)
mat=np.mean(np.dstack(np.hsplit(mat, 200)), axis=2)
sort=np.argsort(np.argmax(mat,axis=1))
pcm=axs[4].imshow(mat[sort, :], cmap=cmap, aspect="auto")
axs[4].tick_params(axis="y", labelsize=ticksizesmall*2)
axs[4].tick_params(axis='x', labelsize=ticksizesmall*2)
axs[4].set_xlabel('x', fontsize=fontsizesmall*2)
axs[4].set_ylabel('cell index', fontsize=fontsizesmall*2)
cb=fig.colorbar(pcm, ax=axs[4])
cb.ax.tick_params(labelsize=ticksizesmall*2) 

axs[0].set_ylim(top=-4, bottom=64)

axs[0].text(-7,-2, r'(A)', fontsize=ticksizesmall*2, weight='bold')
axs[1].text(-7,-2,'(B)',fontsize=ticksizesmall*2, weight='bold')
axs[2].text(-7,-2,r'(C)', fontsize=ticksizesmall*2, weight='bold')
axs[3].text(-7,-2,r'(D)', fontsize=ticksizesmall*2, weight='bold')
axs[4].text(-7,-2, r'(E)', fontsize=ticksizesmall*2, weight='bold')
plt.tight_layout()
name='variables/sorted'+str(env.phi)+'.pdf'
plt.savefig(name)
